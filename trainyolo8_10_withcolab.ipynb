# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics

# %%
# !unzip /content/drive/MyDrive/license_plate.zip -d /content/dataset

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # hoặc yolov8s.pt / yolov8m.pt nếu muốn chính xác hơn

model.train(
    data="/content/dataset/license_plate/dataset.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    name="yolo_lp_train",
    project="/content/runs"
)

# %%
import shutil
import datetime
import os

# Tên thư mục kết quả muốn backup
src_path = "/content/runs/yolo_lp_train2"  

# Tạo tên thư mục đích
timestamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
backup_dir = "/content/drive/MyDrive/backup"
dst_path = f"{backup_dir}/yolo_lp_train2_backup_{timestamp}"

# Tạo thư mục backup nếu chưa có
os.makedirs(backup_dir, exist_ok=True)

# Thực hiện sao lưu
shutil.copytree(src_path, dst_path)
print(f"✅ Backup thành công vào: {dst_path}")

# %% [markdown]
# train với yolov10

# %%
# !wget https://github.com/THU-MIG/yolov10/archive/refs/heads/main.zip -O yolov10.zip
# !unzip yolov10.zip
# %cd yolov10-main
# Out:
# --2025-07-26 13:28:51--  https://github.com/THU-MIG/yolov10/archive/refs/heads/main.zip
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/THU-MIG/yolov10/zip/refs/heads/main [following]
# --2025-07-26 13:28:52--  https://codeload.github.com/THU-MIG/yolov10/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.121.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.121.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘yolov10.zip’
#
# yolov10.zip             [ <=>                ]   1.58M  9.74MB/s    in 0.2s
#
# 2025-07-26 13:28:52 (9.74 MB/s) - ‘yolov10.zip’ saved [1653129]
#
# Archive:  yolov10.zip
# 453c6e38a51e9d1d5a2aa5fb7f1014a711913397
#    creating: yolov10-main/
# ...

# %% [markdown]
# cài đặt thư viện

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install -r requirements.txt

# %% [markdown]
# tải trọng số yolov10

# %%
# !wget https://github.com/THU-MIG/yolov10/releases/download/v1.0/yolov10n.pt

# %%
# %cd /content
# !ls
# Out:
# /content
# dataset  drive	sample_data  yolov10-main  yolov10n.pt	yolov10.zip

# %%
# !yolo task=detect mode=train \
  model=yolov10n.pt \
  data=/content/dataset/license_plate/dataset.yaml \
  epochs=50 \
  imgsz=640 \
  batch=16 \
  patience=20 \
  project=/content/runs \
  name=yolo_lp_train
# Out:
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.0.1+cu117 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import shutil
import datetime
import os

# Tên thư mục kết quả muốn backup
src_path = "/content/runs/yolo_lp_train"  

# Tạo tên thư mục đích
timestamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
backup_dir = "/content/drive/MyDrive/backup"
dst_path = f"{backup_dir}/yolo_lp_trainv10_backup_yolov10_{timestamp}"

# Tạo thư mục backup nếu chưa có
os.makedirs(backup_dir, exist_ok=True)

# Thực hiện sao lưu
shutil.copytree(src_path, dst_path)
print(f"✅ Backup thành công vào: {dst_path}")
# Out:
# ✅ Backup thành công vào: /content/drive/MyDrive/backup/yolo_lp_trainv10_backup_yolov10_2025-07-26_15-00-58

# %%
from ultralytics import YOLO

# Load model
model = YOLO('/content/drive/MyDrive/yolo_lp_train3/weights/best.pt')  # Đường dẫn đến model đã train xong

# Evaluate on test set
metrics = model.val(data='/content/datatest/datatest.yaml', conf=0.25)

# In kết quả chi tiết
print(metrics.results_dict)

# %%
import shutil

# Đường dẫn đích trong Google Drive
save_path = '/content/drive/MyDrive/yolov10_val6'

# Sao chép toàn bộ thư mục kết quả vào Drive
shutil.copytree('runs/detect/val5', save_path, dirs_exist_ok=True)
